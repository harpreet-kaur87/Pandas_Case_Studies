# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("employee_sales_data.csv")

# %%
df
# Out:
#        EmployeeID             Name  Age  Gender Department  Salary  \
# 0               1   David Mcdonald   34    Male         HR   93004
# 1               2    Frank Gilbert   55  Female         IT   80892
# 2               3  Kelly Rodriguez   34    Male         HR   57989
# 3               4    Scott Moss MD   22  Female      Sales  100274
# 4               5      Sara Baxter   57    Male      Sales   95107
# ...           ...              ...  ...     ...        ...     ...
# 49995       49996   Victoria Craig   34    Male      Sales   38735
# 49996       49997     John Jackson   27    Male         HR   86351
# 49997       49998     Kim Martinez   56  Female  Marketing  129036
# 49998       49999   Phillip Bailey   49    Male  Marketing   78316
# 49999       50000      Brian Smith   57  Female         IT  134536
#
#          JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion
# 0      2004-05-05                  3   4650.20        13974       North
# ...

# %%
# shape of the dataset
df.shape
# Out:
# (50000, 11)

# %%
#first 10 rows of the dataset
df.head(10)
# Out:
#    EmployeeID             Name  Age  Gender Department  Salary    JoinDate  \
# 0           1   David Mcdonald   34    Male         HR   93004  2004-05-05
# 1           2    Frank Gilbert   55  Female         IT   80892  2010-12-17
# 2           3  Kelly Rodriguez   34    Male         HR   57989  2014-07-23
# 3           4    Scott Moss MD   22  Female      Sales  100274  2015-05-13
# 4           5      Sara Baxter   57    Male      Sales   95107  2018-04-11
# 5           6    Kaitlin Kelly   59    Male         IT   83222  2011-06-08
# 6           7  Victor Stephens   43  Female    Finance   36355  2017-05-06
# 7           8   Michael Barton   41    Male         IT   64633  2020-01-20
# 8           9        Gary Ross   53  Female  Marketing   57504  2024-01-07
# 9          10   Brandy Sanchez   47    Male         IT  119367  2005-08-10
#
#    PerformanceRating    Bonus  SalesAmount SalesRegion
# 0                  3  4650.20        13974       North
# ...

# %%
#Get the data types of all columns
df.dtypes
# Out:
# EmployeeID             int64
# Name                  object
# Age                    int64
# Gender                object
# Department            object
# Salary                 int64
# JoinDate              object
# PerformanceRating      int64
# Bonus                float64
# SalesAmount            int64
# SalesRegion           object
# dtype: object

# %%
#summary statistics of the dataset
df.describe()
# Out:
#          EmployeeID           Age         Salary  PerformanceRating  \
# count  50000.000000  50000.000000   50000.000000       50000.000000
# mean   25000.500000     40.416540   90079.898120           3.006420
# std    14433.901067     10.967744   34722.882476           1.409829
# min        1.000000     22.000000   30001.000000           1.000000
# 25%    12500.750000     31.000000   59922.000000           2.000000
# 50%    25000.500000     40.000000   90284.500000           3.000000
# 75%    37500.250000     50.000000  120207.000000           4.000000
# max    50000.000000     59.000000  149997.000000           5.000000
#
#               Bonus   SalesAmount
# count  50000.000000  50000.000000
# mean    5403.106467  12480.848820
# std     2841.687815   4323.394015
# min     1500.050000   5000.000000
# 25%     3322.387500   8726.000000
# 50%     5009.500000  12475.000000
# 75%     6671.012500  16214.250000
# max    14997.800000  19999.000000

# %%
#missing values in the dataset
df.isnull().sum()
# Out:
# EmployeeID           0
# Name                 0
# Age                  0
# Gender               0
# Department           0
# Salary               0
# JoinDate             0
# PerformanceRating    0
# Bonus                0
# SalesAmount          0
# SalesRegion          0
# dtype: int64

# %% [markdown]
# # Find all employees who are older than 40.

# %%
employees_40_above = df[df['Age'] > 40]
employees_40_above
# Out:
#        EmployeeID             Name  Age  Gender Department  Salary  \
# 1               2    Frank Gilbert   55  Female         IT   80892
# 4               5      Sara Baxter   57    Male      Sales   95107
# 5               6    Kaitlin Kelly   59    Male         IT   83222
# 6               7  Victor Stephens   43  Female    Finance   36355
# 7               8   Michael Barton   41    Male         IT   64633
# ...           ...              ...  ...     ...        ...     ...
# 49992       49993      Kevin Reyes   43    Male         IT  127150
# 49993       49994    Jennifer King   44    Male         HR   53837
# 49997       49998     Kim Martinez   56  Female  Marketing  129036
# 49998       49999   Phillip Bailey   49    Male  Marketing   78316
# 49999       50000      Brian Smith   57  Female         IT  134536
#
#          JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion
# 1      2010-12-17                  3   4044.60        15107        West
# ...

# %% [markdown]
# # Find all employees in the 'Sales' department.

# %%
sales_dpt = df[df['Department'] == 'Sales']
sales_dpt
# Out:
#        EmployeeID              Name  Age  Gender Department  Salary  \
# 3               4     Scott Moss MD   22  Female      Sales  100274
# 4               5       Sara Baxter   57    Male      Sales   95107
# 17             18  Crystal Martinez   46    Male      Sales   55904
# 18             19  Amanda Mcgee PhD   53  Female      Sales  148993
# 22             23  Vanessa Williams   28    Male      Sales  113833
# ...           ...               ...  ...     ...        ...     ...
# 49963       49964      Jamie Garcia   44  Female      Sales  144645
# 49971       49972       Rhonda Hale   50  Female      Sales   71934
# 49977       49978  Veronica Johnson   22    Male      Sales   57539
# 49988       49989      Jesse Jensen   31    Male      Sales   88124
# 49995       49996    Victoria Craig   34    Male      Sales   38735
#
#          JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion
# 3      2015-05-13                  2   5013.70        17423        East
# ...

# %% [markdown]
# # Find employees who have a salary greater than 80,000.

# %%
salary_above_80000 = df[df['Salary'] > 80000]
salary_above_80000
# Out:
#        EmployeeID            Name  Age  Gender Department  Salary    JoinDate  \
# 0               1  David Mcdonald   34    Male         HR   93004  2004-05-05
# 1               2   Frank Gilbert   55  Female         IT   80892  2010-12-17
# 3               4   Scott Moss MD   22  Female      Sales  100274  2015-05-13
# 4               5     Sara Baxter   57    Male      Sales   95107  2018-04-11
# 5               6   Kaitlin Kelly   59    Male         IT   83222  2011-06-08
# ...           ...             ...  ...     ...        ...     ...         ...
# 49991       49992   Chelsea Gates   46    Male         IT  132285  2009-01-06
# 49992       49993     Kevin Reyes   43    Male         IT  127150  2013-02-13
# 49996       49997    John Jackson   27    Male         HR   86351  2019-07-29
# 49997       49998    Kim Martinez   56  Female  Marketing  129036  2007-11-07
# 49999       50000     Brian Smith   57  Female         IT  134536  2023-01-01
#
# ...

# %% [markdown]
# ## Find all employees with a Performance Rating of 5 and Salary less than 50,000.

# %%
performance_analysis = df[(df['PerformanceRating'] == 5) & (df['Salary'] < 50000)]
performance_analysis
# Out:
#        EmployeeID                 Name  Age  Gender Department  Salary  \
# 19             20        Shannon Ramos   36    Male         IT   37638
# 76             77      Jeffrey Hawkins   52  Female    Finance   42103
# 84             85        Brian Jackson   43    Male  Marketing   37451
# 115           116      Brenda Mcdaniel   23    Male      Sales   39536
# 140           141  Christopher Johnson   47  Female    Finance   48172
# ...           ...                  ...  ...     ...        ...     ...
# 49769       49770       Daniel Edwards   42    Male    Finance   38069
# 49790       49791          Lisa Morris   54  Female         HR   45532
# 49879       49880          Brian Perry   34  Female      Sales   37842
# 49954       49955             Ana Bush   32    Male      Sales   32643
# 49994       49995     Cristina Coleman   30    Male    Finance   38907
#
#          JoinDate  PerformanceRating   Bonus  SalesAmount SalesRegion
# ...

# %% [markdown]
# ## Find employees who joined the company after January 1, 2015.

# %%
employee_joined_after_2015 = df[df['JoinDate'] > '2015-01-01']
employee_joined_after_2015
# Out:
#        EmployeeID              Name  Age  Gender Department  Salary  \
# 3               4     Scott Moss MD   22  Female      Sales  100274
# 4               5       Sara Baxter   57    Male      Sales   95107
# 6               7   Victor Stephens   43  Female    Finance   36355
# 7               8    Michael Barton   41    Male         IT   64633
# 8               9         Gary Ross   53  Female  Marketing   57504
# ...           ...               ...  ...     ...        ...     ...
# 49980       49981     Michael Hogan   47  Female         IT  102564
# 49994       49995  Cristina Coleman   30    Male    Finance   38907
# 49995       49996    Victoria Craig   34    Male      Sales   38735
# 49996       49997      John Jackson   27    Male         HR   86351
# 49999       50000       Brian Smith   57  Female         IT  134536
#
#          JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion
# 3      2015-05-13                  2   5013.70        17423        East
# ...

# %% [markdown]
# ## What is the average salary of employees in each department?

# %%
avg_sal = df.groupby('Department')['Salary'].mean()
avg_sal
# Out:
# Department
# Finance      89871.227932
# HR           90341.357071
# IT           90205.286012
# Marketing    90193.738845
# Sales        89786.280104
# Name: Salary, dtype: float64

# %% [markdown]
# ## What is the total sales amount for each region?

# %%
total_sales_per_region = df.groupby('SalesRegion')['SalesAmount'].sum()
total_sales_per_region
# Out:
# SalesRegion
# East     156968881
# North    155167995
# South    155330712
# West     156574853
# Name: SalesAmount, dtype: int64

# %% [markdown]
# ## Find the number of employees in each department.

# %%
df.Department.value_counts()
# Out:
# IT           10073
# Marketing    10040
# Sales        10007
# HR            9956
# Finance       9924
# Name: Department, dtype: int64

# %% [markdown]
# ## What is the maximum salary in each department?

# %%
max_salary_per_dept = df.groupby('Department')['Salary'].max()
max_salary_per_dept
# Out:
# Department
# Finance      149994
# HR           149995
# IT           149989
# Marketing    149996
# Sales        149997
# Name: Salary, dtype: int64

# %% [markdown]
# ## Find the total bonus paid in each department.

# %%
total_bonus_per_dept = df.groupby('Department')['Bonus'].sum()
total_bonus_per_dept
# Out:
# Department
# Finance      53352131.40
# HR           53856627.70
# IT           54655729.05
# Marketing    54168660.05
# Sales        54122175.15
# Name: Bonus, dtype: float64

# %% [markdown]
# ## Sort the dataset by Salary in descending order.

# %%
sorted_data = df.sort_values(by='Salary', ascending=False)
sorted_data
# Out:
#        EmployeeID              Name  Age  Gender Department  Salary  \
# 36635       36636     Andrew Howell   35  Female      Sales  149997
# 44665       44666      Travis Downs   27  Female  Marketing  149996
# 10364       10365  Kathryn Humphrey   56    Male         HR  149995
# 28529       28530      Daniel Riley   41    Male    Finance  149994
# 42263       42264      Kelly Walker   58  Female         IT  149989
# ...           ...               ...  ...     ...        ...     ...
# 8549         8550   Timothy Navarro   56    Male         IT   30013
# 26469       26470      Daniel Huang   55    Male         HR   30012
# 24493       24494    Kimberly Marks   23  Female    Finance   30007
# 1359         1360     Mariah Meyers   50  Female         HR   30003
# 5931         5932        Lori Mccoy   50    Male  Marketing   30001
#
#          JoinDate  PerformanceRating    Bonus  SalesAmount SalesRegion
# 36635  2008-05-20                  4  7499.85         9045       North
# ...

# %% [markdown]
# ## Sort the employees by Performance Rating in descending order and Name in alphabetical order.

# %%
new_order_rating = df.sort_values(by=['PerformanceRating','Name'], ascending=[False,True])
new_order_rating
# Out:
#        EmployeeID             Name  Age  Gender Department  Salary  \
# 31868       31869    Aaron Acevedo   24    Male      Sales   46614
# 16527       16528  Aaron Acosta MD   49  Female         IT  135666
# 49053       49054   Aaron Anderson   32  Female         IT   87185
# 48555       48556     Aaron Arnold   50  Female      Sales   88846
# 37514       37515     Aaron Brooks   52    Male         HR   37240
# ...           ...              ...  ...     ...        ...     ...
# 25590       25591    Zachary Solis   56  Female         HR   89011
# 25171       25172   Zachary Walker   44  Female    Finance  109171
# 8409         8410  Zachary Webster   36    Male  Marketing  138204
# 16553       16554    Zachary Yates   32  Female         IT   78950
# 42042       42043     Zoe Mcdonald   42  Female         IT   94704
#
#          JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion
# 31868  2024-05-26                  5   4661.40         7414        West
# ...

# %% [markdown]
# ## Sort the employees by Age, and then by Salary within each age group.

# %%
grouping_by_age = df.sort_values(by=['Age','Salary'], ascending=[True,False])
grouping_by_age
# Out:
#        EmployeeID             Name  Age  Gender Department  Salary  \
# 22781       22782    Juan Figueroa   22    Male    Finance  149951
# 238           239  Manuel Thompson   22  Female         IT  149840
# 6058         6059    Robert Thomas   22  Female         IT  149788
# 3819         3820    Tyler Ramirez   22  Female         HR  149775
# 7853         7854    Virginia Cruz   22    Male         HR  149748
# ...           ...              ...  ...     ...        ...     ...
# 20372       20373   Kelly Campbell   59    Male         HR   30507
# 11873       11874   Matthew Bowman   59  Female         IT   30504
# 23602       23603  James Gutierrez   59  Female  Marketing   30320
# 8433         8434      Taylor Cole   59  Female      Sales   30292
# 45579       45580      Erica Gomez   59    Male  Marketing   30125
#
#          JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion
# 22781  2004-04-02                  4   7497.55        17114        East
# ...

# %% [markdown]
# ## Find the second-highest salary in each department.

# %%
second_highest_salary = (
                df.groupby('Department')['Salary']
               .apply(lambda x:x.nlargest(2).iloc[-1] if len(x) > 1 else None).reset_index()
                .rename(columns={'Salary':'Second_Highest_Salary'})
)
second_highest_salary
# Out:
#   Department  Second_Highest_Salary
# 0    Finance                 149988
# 1         HR                 149956
# 2         IT                 149983
# 3  Marketing                 149969
# 4      Sales                 149989

# %% [markdown]
# ## Convert the 'JoinDate' column to a datetime format if it is not already.

# %%
df['JoinDate'] = pd.to_datetime(df['JoinDate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         50000 non-null  int64
#  1   Name               50000 non-null  object
#  2   Age                50000 non-null  int64
#  3   Gender             50000 non-null  object
#  4   Department         50000 non-null  object
#  5   Salary             50000 non-null  int64
#  6   JoinDate           50000 non-null  datetime64[ns]
#  7   PerformanceRating  50000 non-null  int64
#  8   Bonus              50000 non-null  float64
#  9   SalesAmount        50000 non-null  int64
#  10  SalesRegion        50000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 4.2+ MB

# %% [markdown]
# ## Extract the year from the 'JoinDate' and create a new column 'JoinYear'.

# %%
df['JoinYear'] = df['JoinDate'].dt.year
df.head(5)
# Out:
#    EmployeeID             Name  Age  Gender Department  Salary   JoinDate  \
# 0           1   David Mcdonald   34    Male         HR   93004 2004-05-05
# 1           2    Frank Gilbert   55  Female         IT   80892 2010-12-17
# 2           3  Kelly Rodriguez   34    Male         HR   57989 2014-07-23
# 3           4    Scott Moss MD   22  Female      Sales  100274 2015-05-13
# 4           5      Sara Baxter   57    Male      Sales   95107 2018-04-11
#
#    PerformanceRating    Bonus  SalesAmount SalesRegion  JoinYear
# 0                  3  4650.20        13974       North      2004
# 1                  3  4044.60        15107        West      2010
# 2                  4  2899.45         6299       South      2014
# 3                  2  5013.70        17423        East      2015
# 4                  5  9510.70        14279       South      2018

# %% [markdown]
# ## Create a new column 'AgeGroup' where employees above 50 are 'Senior' and others are 'Junior'.

# %%
df['AgeGroup'] = df['Age'].apply(lambda x:'Senior' if x > 50 else 'Junior')
df.head(5)
# Out:
#    EmployeeID             Name  Age  Gender Department  Salary   JoinDate  \
# 0           1   David Mcdonald   34    Male         HR   93004 2004-05-05
# 1           2    Frank Gilbert   55  Female         IT   80892 2010-12-17
# 2           3  Kelly Rodriguez   34    Male         HR   57989 2014-07-23
# 3           4    Scott Moss MD   22  Female      Sales  100274 2015-05-13
# 4           5      Sara Baxter   57    Male      Sales   95107 2018-04-11
#
#    PerformanceRating    Bonus  SalesAmount SalesRegion  JoinYear AgeGroup
# 0                  3  4650.20        13974       North      2004   Junior
# 1                  3  4044.60        15107        West      2010   Senior
# 2                  4  2899.45         6299       South      2014   Junior
# 3                  2  5013.70        17423        East      2015   Junior
# 4                  5  9510.70        14279       South      2018   Senior

# %% [markdown]
# ## Calculate the percentage of each department’s total salary in the overall salary expenditure.

# %%
department_salary = df.groupby('Department')['Salary'].sum()
total_salary = department_salary.sum()

# %%
department_salary_percentage = (department_salary / total_salary) * 100
department_salary_percentage
# Out:
# Department
# Finance      19.802022
# HR           19.969795
# IT           20.174042
# Marketing    20.105377
# Sales        19.948764
# Name: Salary, dtype: float64

# %% [markdown]
# ## Find the employees who are in the 'Sales' department, have a salary greater than 80,000, and joined after 2018.

# %%
data_from_sales_dept = df[(df['Department'] == 'Sales') & (df['Salary'] > 80000) & (df['JoinYear'] > 2018)]
data_from_sales_dept
# Out:
#        EmployeeID             Name  Age  Gender Department  Salary   JoinDate  \
# 83             84     Samuel Allen   36    Male      Sales  133770 2019-03-13
# 85             86     Michael Mann   49    Male      Sales  145703 2021-03-14
# 94             95       Penny West   25    Male      Sales  144950 2022-05-05
# 96             97      Wayne Green   56  Female      Sales  105444 2020-04-06
# 221           222      Maria Jones   41  Female      Sales  139197 2023-12-27
# ...           ...              ...  ...     ...        ...     ...        ...
# 49899       49900    Julie Gardner   36  Female      Sales  102940 2023-05-13
# 49901       49902     Selena Brown   40    Male      Sales  114873 2023-09-26
# 49925       49926  Stephen Flowers   28  Female      Sales  124102 2022-11-30
# 49945       49946     Andre Mccann   48  Female      Sales  102490 2023-12-30
# 49948       49949    Joseph Newton   58    Male      Sales  134328 2022-02-05
#
# ...

# %% [markdown]
# ## Find all employees with a performance rating of 4 or 5 who have received a bonus greater than 7,000.

# %%
high_performance_rating = df[(df['PerformanceRating'] >= 4) & (df['Bonus'] > 7000)]
high_performance_rating
# Out:
#        EmployeeID              Name  Age  Gender Department  Salary  \
# 4               5       Sara Baxter   57    Male      Sales   95107
# 18             19  Amanda Mcgee PhD   53  Female      Sales  148993
# 42             43    Pamela Ramirez   43  Female      Sales  128002
# 51             52      Nathan Riley   36  Female  Marketing   81801
# 53             54    Phillip Romero   59    Male         IT  107013
# ...           ...               ...  ...     ...        ...     ...
# 49958       49959    Kenneth Taylor   25  Female         HR  139519
# 49970       49971     Rebecca Jones   44    Male         IT  136135
# 49976       49977      Andrew Haney   55  Female         HR   96494
# 49979       49980    Cheryl Merritt   59  Female         HR  148107
# 49999       50000       Brian Smith   57  Female         IT  134536
#
#         JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion  \
# 4     2018-04-11                  5   9510.70        14279       South
# ...

# %% [markdown]
# ## Find the average sales amount by region for employees with a performance rating greater than 3.

# %%
avg_sales_amount = df[df['PerformanceRating'] > 3].groupby('SalesRegion')['SalesAmount'].mean()
avg_sales_amount
# Out:
# SalesRegion
# East     12416.043246
# North    12415.398614
# South    12418.456552
# West     12517.090854
# Name: SalesAmount, dtype: float64

# %% [markdown]
# ## What is the average salary and total sales amount by department?

# %%
dept_analysis = df.groupby('Department')[['Salary','SalesAmount']].agg({'Salary':'mean','SalesAmount':'sum'})
dept_analysis
# Out:
#                   Salary  SalesAmount
# Department
# Finance     89871.227932    124091524
# HR          90341.357071    123540680
# IT          90205.286012    125614070
# Marketing   90193.738845    125786443
# Sales       89786.280104    125009724

# %% [markdown]
# ## Find the department with the highest total salary expenditure.

# %%
dept_with_highest_sal_exp = df.groupby('Department')['Salary'].sum().idxmax()
dept_with_highest_sal_exp
# Out:
# 'IT'

# %% [markdown]
# ## Find the total salary expenditure and the number of employees in each department where the total salary exceeds 2 million.

# %%
department_summary = df.groupby('Department').agg({'Salary':'sum','EmployeeID':'count'})
department_summary[department_summary['Salary'] > 2000000]
# Out:
#                Salary  EmployeeID
# Department
# Finance     891882066        9924
# HR          899438551        9956
# IT          908637846       10073
# Marketing   905545138       10040
# Sales       898491305       10007

# %% [markdown]
# ## Calculate the median salary by department and performance rating.

# %%
median_salary = df.groupby(['Department','PerformanceRating'])['Salary'].median()
median_salary
# Out:
# Department  PerformanceRating
# Finance     1                    88718.5
#             2                    91134.0
#             3                    89277.0
#             4                    89076.0
#             5                    90628.5
# HR          1                    90519.0
#             2                    90672.0
#             3                    89752.5
#             4                    91549.0
#             5                    90564.5
# IT          1                    91278.5
#             2                    89034.0
#             3                    90249.0
#             4                    91631.0
#             5                    90501.0
# Marketing   1                    89839.0
#             2                    90153.0
#             3                    91785.0
#             4                    88548.0
#             5                    90969.0
# Sales       1                    88873.0
#             2                    89258.0
# ...

# %% [markdown]
# ## Find the department-wise distribution of employee performance ratings (frequency of each rating).

# %%
dist_of_rating = df.groupby(['Department','PerformanceRating']).size().unstack(fill_value=0)
dist_of_rating
# Out:
# PerformanceRating     1     2     3     4     5
# Department
# Finance            1948  2002  1995  2037  1942
# HR                 1996  2018  1956  2026  1960
# IT                 1974  1986  2048  2014  2051
# Marketing          1969  2007  2069  2022  1973
# Sales              1966  1995  1999  2010  2037

# %% [markdown]
# ## Rank employees within each department based on their sales amount. If two employees have the same sales amount, rank them by salary.

# %%
df['SalesRank'] = ( 
            df.sort_values(['SalesAmount','Salary'], ascending=[False,False]).groupby('Department')
            .cumcount() + 1
)

# %%
df.sort_values(by=['Department','SalesRank'], ascending=[True,True])
# Out:
#        EmployeeID                 Name  Age  Gender Department  Salary  \
# 36581       36582     Charles Williams   53  Female    Finance   77265
# 16374       16375     Stephanie Morris   47  Female    Finance  146870
# 29112       29113     Kimberly Carroll   22  Female    Finance  121775
# 26576       26577      Jorge Wilkinson   58  Female    Finance  104418
# 4342         4343      Randy Hernandez   30    Male    Finance  115221
# ...           ...                  ...  ...     ...        ...     ...
# 32460       32461          Megan Frost   35    Male      Sales  101700
# 7811         7812         Sean Beltran   22    Male      Sales  102898
# 38155       38156       Brad Carpenter   50    Male      Sales   60850
# 7479         7480          James Myers   40  Female      Sales   57110
# 11738       11739  Elizabeth Hernandez   47    Male      Sales  144798
#
#         JoinDate  PerformanceRating     Bonus  SalesAmount SalesRegion  \
# ...

# %% [markdown]
# ## Find the top 3 highest-paid employees in each department.

# %%
df.sort_values(by=['Department','Salary'], ascending=[True,False]).groupby('Department').head(3)
# Out:
#        EmployeeID                Name  Age  Gender Department  Salary  \
# 28529       28530        Daniel Riley   41    Male    Finance  149994
# 33218       33219    Angelica Hammond   50  Female    Finance  149988
# 13322       13323       Cheryl Nelson   37  Female    Finance  149984
# 10364       10365    Kathryn Humphrey   56    Male         HR  149995
# 42527       42528      Michelle James   52    Male         HR  149956
# 24762       24763         Jodi Gibson   39  Female         HR  149952
# 42263       42264        Kelly Walker   58  Female         IT  149989
# 37130       37131        Kenneth Bell   39  Female         IT  149983
# 23973       23974       Tammy Montoya   52    Male         IT  149978
# 44665       44666        Travis Downs   27  Female  Marketing  149996
# 15772       15773     Cassandra Jones   41    Male  Marketing  149969
# 44517       44518       Nicholas Hill   37    Male  Marketing  149969
# ...

# %% [markdown]
# ## Create a new DataFrame that combines all employees from the 'Sales' department with the sales data (e.g., SalesRegion and SalesAmount) from df.

# %%
sales_df = df[df['Department'] == 'Sales'][['EmployeeID','SalesAmount','SalesRegion']]

# %%
sales_df
# Out:
#        EmployeeID  SalesAmount SalesRegion
# 3               4        17423        East
# 4               5        14279       South
# 17             18        16318       North
# 18             19        10746       North
# 22             23         5348        East
# ...           ...          ...         ...
# 49963       49964         5482       North
# 49971       49972        11978        East
# 49977       49978         5454        West
# 49988       49989        13415       North
# 49995       49996         5807        West
#
# [10007 rows x 3 columns]

# %% [markdown]
# ## Find the total salary expenditure in each year.

# %%
total_salary_exp_by_year = df.groupby('JoinYear')['Salary'].sum()
total_salary_exp_by_year
# Out:
# JoinYear
# 2000    174254286
# 2001    182685374
# 2002    184547324
# 2003    183320872
# 2004    183256130
# 2005    185604509
# 2006    179740932
# 2007    184693699
# 2008    180111324
# 2009    180514094
# 2010    182395124
# 2011    184334640
# 2012    178428868
# 2013    187635451
# 2014    177726720
# 2015    182542597
# 2016    174377406
# 2017    177498106
# 2018    182391539
# 2019    172449995
# 2020    183172245
# 2021    179773262
# 2022    179041139
# 2023    175868972
# 2024    167630298
# Name: Salary, dtype: int64

# %% [markdown]
# ## Find the number of new hires each year (based on the JoinDate).

# %%
count_of_new_hires = df.groupby('JoinYear')['EmployeeID'].count()
count_of_new_hires
# Out:
# JoinYear
# 2000    1950
# 2001    2029
# 2002    2079
# 2003    2068
# 2004    2043
# 2005    2029
# 2006    1980
# 2007    2042
# 2008    2004
# 2009    2015
# 2010    1994
# 2011    2044
# 2012    1984
# 2013    2092
# 2014    1989
# 2015    2005
# 2016    1937
# 2017    1961
# 2018    2021
# 2019    1923
# 2020    2000
# 2021    1989
# 2022    2031
# 2023    1938
# 2024    1853
# Name: EmployeeID, dtype: int64

# %% [markdown]
# ## Create a new column that classifies employees into 'High' and 'Low' salary categories, where 'High' means salary above 100,000.

# %%
df['SalaryCategory'] = df['Salary'].apply(lambda x: 'High' if x > 100000 else 'Low')

# %% [markdown]
# ## Calculate the correlation between Salary and SalesAmount.

# %%
df[['Salary','SalesAmount']].corr()
# Out:
#                Salary  SalesAmount
# Salary       1.000000     0.001813
# SalesAmount  0.001813     1.000000
